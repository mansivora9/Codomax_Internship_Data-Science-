# %% [markdown]
# # Student Data Dashboard

# %% [markdown]
# # 📊 Student Data Dashboard
#
# ### Codomax Data Science Internship
#
# **Created by:** Mansi Vora
#
# This dashboard analyzes student data using **Python, Pandas, and Matplotlib**.

# %%
# import libraries
import pandas as pd
import matplotlib.pyplot as plt

# %%
# load dataset
df = pd.read_csv("data.csv")
print(df)
df.columns = df.columns.str.strip()

df.head()
# Out:
#    student_id     name  age  gender       department
# 0           1    Mansi   21  female              CSE
# 1           2   Krisha   22  female              CSE
# 2           3   Rutvik   29    male               IT
# 3           4    Manas   27    male               IT
# 4           5    Priya   29  female           Design
# 5           6    Payal   32  female   fashion design
# 6           7  Parthiv   22    male            civil
# 7           8   bhrugu   21    male       mechanical
# 8           9    nawaz   22    male       electrical
# 9          10    arjun   20    male  micro-biologist
#    student_id    name  age  gender department
# 0           1   Mansi   21  female        CSE
# 1           2  Krisha   22  female        CSE
# 2           3  Rutvik   29    male         IT
# 3           4   Manas   27    male         IT
# 4           5   Priya   29  female     Design

# %%
print("Dataset Shape:", df.shape)

print("\nColumn Names:")
print(df.columns)

print("\nDataset Information:")
df.info()

print("\nSummary Statistics:")
display(df.describe())
# Out:
# Dataset Shape: (10, 5)
#
# Column Names:
# Index(['student_id', 'name', 'age', 'gender', 'department'], dtype='object')
#
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   student_id  10 non-null     int64
#  1   name        10 non-null     object
#  2   age         10 non-null     int64
#  3   gender      10 non-null     object
#  4   department  10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 532.0+ bytes
#
# Summary Statistics:
#        student_id        age
# count    10.00000  10.000000
# mean      5.50000  24.500000
# std       3.02765   4.301163
# min       1.00000  20.000000
# 25%       3.25000  21.250000
# 50%       5.50000  22.000000
# 75%       7.75000  28.500000
# max      10.00000  32.000000

# %%
# department analysis
department_count = df["department"].value_counts()

print(department_count)
# Out:
# department
# CSE                2
# IT                 2
# Design             1
# fashion design     1
# civil              1
# mechanical         1
# electrical         1
# micro-biologist    1
# Name: count, dtype: int64

# %%
# gender analysis
gender_count = df["gender"].value_counts()

print(gender_count)
# Out:
# gender
# male      6
# female    4
# Name: count, dtype: int64

# %%
# average age
average_age = df["age"].mean()

print("Average Age:", average_age)
# Out:
# Average Age: 24.5

# %%
# bar chart
plt.figure(figsize=(6,4))

plt.bar(department_count.index, department_count.values)

plt.title("Students in Each Department")
plt.xlabel("Department")
plt.ylabel("Number of Students")

plt.xticks(rotation=45)

plt.show()

# %%
# pie chart
plt.figure(figsize=(6,4))

plt.pie(
    gender_count.values,
    labels=gender_count.index,
    autopct="%1.1f%%",
    startangle=90
)

plt.title("Gender Distribution")

plt.show()

# %%
# histogram
plt.figure(figsize=(6,4))

plt.hist(df["age"], bins=5)

plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Frequency")

plt.show()

# %% [markdown]
# THANK YOU
